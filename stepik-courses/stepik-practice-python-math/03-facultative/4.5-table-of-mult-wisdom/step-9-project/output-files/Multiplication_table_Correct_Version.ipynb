# %%
# Для построения таблицы будем использовать библиотеку pandas
import pandas as pd

# %%
# При решении использовались следующие версии
import sys
print(f'python: {sys.version}',
     f'pandas: {pd.__version__}', sep='\n' )
# Out:
# python: 3.8.10 (default, May 19 2021, 18:05:58)
# [GCC 7.3.0]
# pandas: 1.2.4

# %%
# Функция умножения по методу «Мудреца»
def wisdom_multiplication(x, y, length_check=True):
    p1 = str((100 - (100 - x) - (100 - y)))  # Первые две цифры результата
    p2 = str((100 - x) * (100 - y))  # Вторые две цифры результата
    # Если требуется, удостоверяемся, что вторых цифр действительно две
    if length_check:
        # когда результат подсчёта второй половины состоит лишь из одной цифры
        # добавим 0 между ними
        if len(p2) < 2:
            return int(p1 + '0' + p2)

    return int(p1 + p2)

# функция для проверки результата перемножения по методу «Мудреца»
def wisdom_multiplication_check(x: int, y: int) -> dict:
    correct = x*y
    # отдельной проверим без проверки длины
    no_check = correct == wisdom_multiplication(x, y, False)
    # если результат перемножения без проверки длины верен,
    # то и с проверкой тоже будет верный результат
    if no_check:
        return {"no_check": True,
                "check": True}
    # если без проверки длины результат оказался неверным,
    # проверим какой результат даст метод с использованием проверкой длины
    else:
        return {"no_check": no_check,
                "check": correct == wisdom_multiplication(x, y, True)}

# функция для покраски ячеек
def wisdom_style(val, no_check_color='green', check_color='orange'):
    # извлекаем числа из строчных данных, записанных в ячейках
    n, m = (int(x) for x in val.split('x'))
    
    # проверяем верность метода «Мудреца»
    w_check = wisdom_multiplication_check(n, m)
    if w_check["no_check"]:
        return f"background-color: {no_check_color}"
    elif w_check["check"]:
        return f"background-color: {check_color}"
    else:
        return ""

# %%
# настраиваем отображение таблиц в pandas так, чтобы в нашей таблице отображались все столбцы и строки
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
# дополнительно укажем, чтобы столбец расширялся, если его ширине не хватит для отображения содержимого
pd.set_option("display.max_colwidth", None)

# %%
# задачём границы таблицы
start, stop = 10, 99

# создаём таблицу, заполняя строковыми значениями выражающими умножение n на m.
table = pd.DataFrame([[f'{n}x{m}' for n in range(start, stop+1)] for m in range(start, stop+1)],
                     index=range(start, stop+1), columns=range(start, stop+1), )

# красим ячейки таблицы в зависимости от верности результатов перемножения
# зелёные ячейки → те, где результат расчёта по методу «Мудреца» верен и без проверки на длину
# оранжевые ячейки → те, где результат расчёта по методу «Мудреца» верено, но только с проверкой на длину
styled = table.style.applymap(wisdom_style, no_check_color='lightgreen', check_color='orange')

# сохраним получившуюся таблицу в файл
with open('wisdom_table_correctness.html', 'w') as f:
    f.write(styled.render())

# отобразим получившуюся таблицу таблицу тут
styled
# Out:
# <style  type="text/css" >
# #T_a9162_row0_col80,#T_a9162_row0_col89,#T_a9162_row1_col79,#T_a9162_row1_col89,#T_a9162_row2_col78,#T_a9162_row2_col89,#T_a9162_row3_col77,#T_a9162_row3_col89,#T_a9162_row4_col76,#T_a9162_row4_col89,#T_a9162_row5_col75,#T_a9162_row5_col89,#T_a9162_row6_col74,#T_a9162_row6_col89,#T_a9162_row7_col73,#T_a9162_row7_col89,#T_a9162_row8_col72,#T_a9162_row8_col89,#T_a9162_row9_col71,#T_a9162_row9_col89,#T_a9162_row10_col70,#T_a9162_row10_col89,#T_a9162_row11_col69,#T_a9162_row11_col89,#T_a9162_row12_col68,#T_a9162_row12_col89,#T_a9162_row13_col67,#T_a9162_row13_col89,#T_a9162_row14_col66,#T_a9162_row14_col89,#T_a9162_row15_col65,#T_a9162_row15_col89,#T_a9162_row16_col64,#T_a9162_row16_col89,#T_a9162_row17_col63,#T_a9162_row17_col89,#T_a9162_row18_col62,#T_a9162_row18_col89,#T_a9162_row19_col61,#T_a9162_row19_col89,#T_a9162_row20_col60,#T_a9162_row20_col89,#T_a9162_row21_col59,#T_a9162_row21_col89,#T_a9162_row22_col58,#T_a9162_row22_col89,#T_a9162_row23_col57,#T_a9162_row23_col89,#T_a9162_row24_col56,#T_a9162_row24_col89,#T_a9162_row25_col55,#T_a9162_row25_col89,#T_a9162_row26_col54,#T_a9162_row26_col89,#T_a9162_row27_col53,#T_a9162_row27_col89,#T_a9162_row28_col52,#T_a9162_row28_col89,#T_a9162_row29_col51,#T_a9162_row29_col89,#T_a9162_row30_col50,#T_a9162_row30_col89,#T_a9162_row31_col49,#T_a9162_row31_col89,#T_a9162_row32_col48,#T_a9162_row32_col89,#T_a9162_row33_col47,#T_a9162_row33_col89,#T_a9162_row34_col46,#T_a9162_row34_col89,#T_a9162_row35_col45,#T_a9162_row35_col89,#T_a9162_row36_col44,#T_a9162_row36_col89,#T_a9162_row37_col43,#T_a9162_row37_col89,#T_a9162_row38_col42,#T_a9162_row38_col89,#T_a9162_row39_col41,#T_a9162_row39_col89,#T_a9162_row40_col40,#T_a9162_row40_col89,#T_a9162_row41_col39,#T_a9162_row41_col88,#T_a9162_row41_col89,#T_a9162_row42_col38,#T_a9162_row42_col88,#T_a9162_row42_col89,#T_a9162_row43_col37,#T_a9162_row43_col88,#T_a9162_row43_col89,#T_a9162_row44_col36,#T_a9162_row44_col88,#T_a9162_row44_col89,#T_a9162_row45_col35,#T_a9162_row45_col88,#T_a9162_row45_col89,#T_a9162_row46_col34,#T_a9162_row46_col88,#T_a9162_row46_col89,#T_a9162_row47_col33,#T_a9162_row47_col88,#T_a9162_row47_col89,#T_a9162_row48_col32,#T_a9162_row48_col88,#T_a9162_row48_col89,#T_a9162_row49_col31,#T_a9162_row49_col88,#T_a9162_row49_col89,#T_a9162_row50_col30,#T_a9162_row50_col88,#T_a9162_row50_col89,#T_a9162_row51_col29,#T_a9162_row51_col88,#T_a9162_row51_col89,#T_a9162_row52_col28,#T_a9162_row52_col88,#T_a9162_row52_col89,#T_a9162_row53_col27,#T_a9162_row53_col88,#T_a9162_row53_col89,#T_a9162_row54_col26,#T_a9162_row54_col88,#T_a9162_row54_col89,#T_a9162_row55_col25,#T_a9162_row55_col88,#T_a9162_row55_col89,#T_a9162_row56_col24,#T_a9162_row56_col88,#T_a9162_row56_col89,#T_a9162_row57_col23,#T_a9162_row57_col87,#T_a9162_row57_col88,#T_a9162_row57_col89,#T_a9162_row58_col22,#T_a9162_row58_col87,#T_a9162_row58_col88,#T_a9162_row58_col89,#T_a9162_row59_col21,#T_a9162_row59_col87,#T_a9162_row59_col88,#T_a9162_row59_col89,#T_a9162_row60_col20,#T_a9162_row60_col87,#T_a9162_row60_col88,#T_a9162_row60_col89,#T_a9162_row61_col19,#T_a9162_row61_col87,#T_a9162_row61_col88,#T_a9162_row61_col89,#T_a9162_row62_col18,#T_a9162_row62_col87,#T_a9162_row62_col88,#T_a9162_row62_col89,#T_a9162_row63_col17,#T_a9162_row63_col87,#T_a9162_row63_col88,#T_a9162_row63_col89,#T_a9162_row64_col16,#T_a9162_row64_col87,#T_a9162_row64_col88,#T_a9162_row64_col89,#T_a9162_row65_col15,#T_a9162_row65_col87,#T_a9162_row65_col88,#T_a9162_row65_col89,#T_a9162_row66_col14,#T_a9162_row66_col86,#T_a9162_row66_col87,#T_a9162_row66_col88,#T_a9162_row66_col89,#T_a9162_row67_col13,#T_a9162_row67_col86,#T_a9162_row67_col87,#T_a9162_row67_col88,#T_a9162_row67_col89,#T_a9162_row68_col12,#T_a9162_row68_col86,#T_a9162_row68_col87,#T_a9162_row68_col88,#T_a9162_row68_col89,#T_a9162_row69_col11,#T_a9162_row69_col86,#T_a9162_row69_col87,#T_a9162_row69_col88,#T_a9162_row69_col89,#T_a9162_row70_col10,#T_a9162_row70_col86,#T_a9162_row70_col87,#T_a9162_row70_col88,#T_a9162_row70_col89,#T_a9162_ ...
